# %%
import cv2
print(cv2.__version__)
# Out:
# 5.0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
image=np.zeros((16,16,3),dtype='uint8')
image[4:10,3:4]=[255,255,0]
image[4:10,4:5]=[255,0,0]
image[4:10,5:6]=[0,255,0]
image[4:10,6:7]=[0,0,255]

plt.imshow(image,cmap='jet')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
image=np.zeros((16,16,3),dtype='uint8')
image[4:10,3:4]=[255,255,0]
image[4:10,4:5]=[255,0,0]
image[4:10,5:6]=[0,255,0]
image[4:10,6:7]=[0,0,255]

cv2.imshow('image',image)
cv2.imwrite('image.png',image)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
import numpy as np
import matplotlib.pyplot as plt
image=np.zeros((16,16,3),dtype='uint8')
image[4:10,3:4]=(255, 165, 0)
image[4:10,4:5]=(255, 255, 255)
image[4:10,5:6]=(0, 128, 0)


cv2.imshow('image',image)
cv2.imwrite('image2.png',image)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
# Out:
# <class 'numpy.ndarray'>
